# %% [markdown]
# Make sure that here you have already:
# * Made sure that the files are cleaned and you have have removed publications that you don't need
# * That you have run the DBLPExampleParser to get all VIS authors
#
# We now need to run the dedupe again over all authors since there are always changes to the dataset made on the DBLP side

# %%
import pandas as pd

dblpauthors = pd.read_csv("author-files/dblpAuthors-2022.tsv",keep_default_na=False,sep='\t')


print(dblpauthors.info())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 dblpauthors = pd.read_csv("author-files/dblpAuthors-2022.tsv",keep_default_na=False,sep='\t')
#       6 print(dblpauthors.info())
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
currentvispubdataupdate = "vispubdata-current/IEEE VIS papers 1990-2021 - Main dataset-update-in-progress.csv"
vispubdata = pd.read_csv(currentvispubdataupdate)
#vispubdata = pd.read_csv("IEEE VIS papers 1990-2018 - Main dataset.csv")
vispubdata['AuthorNames-Deduped'] = vispubdata['AuthorNames-Deduped'].astype(str)

print(vispubdata.info())
print(vispubdata.index)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621 entries, 0 to 3620
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Conference              3621 non-null   object
#  1   Year                    3621 non-null   int64
#  2   Title                   3621 non-null   object
#  3   DOI                     3621 non-null   object
#  4   Link                    3621 non-null   object
#  5   FirstPage               3588 non-null   object
#  6   LastPage                3578 non-null   object
#  7   PaperType               3621 non-null   object
#  8   Abstract                3549 non-null   object
#  9   AuthorNames-Deduped     3621 non-null   object
#  10  AuthorNames             3617 non-null   object
#  11  AuthorAffiliation       3491 non-null   object
#  12  InternalReferences      2746 non-null   object
#  13  AuthorKeywords          2641 non-null   object
# ...

# %%
dblpauthors['DOI-short'] = ""

dblpauthors.loc[dblpauthors['DOI'].str.contains("doi.*org"),'DOI-short'] = dblpauthors['DOI']
dblpauthors['DOI-short'] = dblpauthors['DOI-short'].str.replace("https://doi.*org/","",regex=True)
dblpauthors['DOI-short'] = dblpauthors['DOI-short'].str.replace("http://doi.*org/","",regex=True)


dblpauthors.to_csv("author-files/dblpauthors-DEBUG.csv")
dblpauthors.head(15)
# Out:
#                           Key  \
# 0   conf/ieeevast/00010RAMA17
# 1   conf/ieeevast/0001LXZHY19
# 2          conf/ieeevast/2006
# 3          conf/ieeevast/2007
# 4          conf/ieeevast/2008
# 5          conf/ieeevast/2009
# 6          conf/ieeevast/2010
# 7          conf/ieeevast/2011
# 8          conf/ieeevast/2012
# 9          conf/ieeevast/2014
# 10         conf/ieeevast/2015
# 11         conf/ieeevast/2016
# 12         conf/ieeevast/2017
# 13         conf/ieeevast/2018
# 14         conf/ieeevast/2019
#
#                                             PublTitle  Year      Title  \
# 0   The Role of Explicit Knowledge: A Conceptual M...  2017       VAST
# 1   EarthquakeAware: Visual Analytics for Understa...  2019       VAST
# 2   1st IEEE Symposium On Visual Analytics Science...  2006  IEEE VAST
# 3   2nd IEEE Symposium on Visual Analytics Science...  2007  IEEE VAST
# 4   3rd IEEE Symposium on Visual Analytics Science...  2008  IEEE VAST
# ...

# %%
dois_not_in_dblp = []

for doi in vispubdata.DOI:
    #find the DOI in the dblpauthors
    
    #print(doi)
    found = dblpauthors['DOI-short'].eq(doi).any() 
    #print(found)
   
    if(found != False):

        dblp_rowindex = dblpauthors.index[dblpauthors['DOI-short'] == doi].tolist()[0]
        #print(dblp_rowindex)
        vispubdata_rowindex = pd.Index(vispubdata.DOI).get_loc(doi)
        #print(vispubdata_rowindex)
        
        vispubdata_deduped_authors = vispubdata.at[vispubdata_rowindex,'AuthorNames-Deduped']

        if vispubdata_deduped_authors != dblpauthors.at[dblp_rowindex,'Authors']:
            dblp_deduped_authors = dblpauthors.at[dblp_rowindex,'Authors']
            print("DOI: " +dblpauthors.at[dblp_rowindex,'DOI'] + " " + vispubdata.at[vispubdata_rowindex,'DOI'])
            print("Existing authors do not match new authors:")
            print(" old: "+str(vispubdata_deduped_authors))
            print(" new: "+str(dblp_deduped_authors))
            vispubdata.at[vispubdata_rowindex,'AuthorNames-Deduped'] = dblp_deduped_authors
        #else:
            #print("Old authors match new authors")
    else:
        dois_not_in_dblp.append(doi)

print(len(dois_not_in_dblp))
# Out:
# DOI: https://doi.org/10.1109/VISUAL.1990.146361 10.1109/VISUAL.1990.146361
# Existing authors do not match new authors:
#  old: William L. Hibbard;David A. Santek
#  new: Bill Hibbard;David A. Santek
# DOI: https://doi.org/10.1109/VISUAL.1991.175776 10.1109/VISUAL.1991.175776
# Existing authors do not match new authors:
#  old: H. W. Park;K. S. Eo;D. L. Kim;B. K. Choi;Yongmin Kim 0001;T. Alexander
#  new: Hyun Wook Park;Kil-Su Eo;D. L. Kim;B. K. Choi;Yongmin Kim 0001;Thomas Alexander
# DOI: https://doi.org/10.1109/VISUAL.1992.235215 10.1109/VISUAL.1992.235215
# Existing authors do not match new authors:
#  old: William L. Hibbard;Charles R. Dyer;Brian E. Paul
#  new: Bill Hibbard;Charles R. Dyer;Brian E. Paul
# DOI: https://doi.org/10.1109/VISUAL.1992.235216 10.1109/VISUAL.1992.235216
# Existing authors do not match new authors:
#  old: X. Wu;Y. Fang
#  new: Xiaolin Wu;Yonggang Fang
# DOI: https://doi.org/10.1109/VISUAL.1992.235175 10.1109/VISUAL.1992.235175
# ...

# %%
vispubdata.to_csv("author-files/Vispubdata-updatedAuthors.csv",index =False)
##now copy the names over to the main spreadsheet and download the whole csv again

print(dois_not_in_dblp)

#DOIs regularly  not found:
#10.0000/00000001 -> M paper
#10.0000/00000002 -> M paper
#10.1109/VISUAL.1991.175767 --> M paper
#10.1109/VISUAL.1991.175823 -- 28 --> M papers (panels etc.)
#10.1109/VISUAL.1992.235182 -- 87 --> M papers
#10.1109/INFVIS.2003.1249000 --> M paper
#10.1109/VISUAL.2003.1250348 --> M paper
#10.1109/INFVIS.2004.20 --> M paper, missing in DBLP
#10.1109/INFVIS.2004.73 --> M paper, missing in DBLP
#10.1109/INFVIS.2005.1532153 --> M paper

#after this copy the names over to vispubdata
# Out:
# ['10.1109/VISUAL.1991.175767', '10.1109/VISUAL.1991.175823', '10.1109/VISUAL.1991.175824', '10.1109/VISUAL.1991.175825', '10.1109/VISUAL.1991.175826', '10.1109/VISUAL.1991.175827', '10.1109/VISUAL.1991.175828', '10.1109/VISUAL.1992.235182', '10.1109/VISUAL.1992.235183', '10.1109/VISUAL.1992.235184', '10.1109/VISUAL.1992.235185', '10.1109/VISUAL.1992.235186', '10.1109/VISUAL.1992.235187', '10.0000/00000001', '10.1109/INFVIS.2003.1249000', '10.1109/VISUAL.2003.1250348', '10.1109/INFVIS.2004.20', '10.1109/INFVIS.2004.73', '10.1109/INFVIS.2005.1532153']

# %%
#let's do some error checking
from Levenshtein import *

vispubdata['AuthorEditDistance'] = -1

for index, row in vispubdata.iterrows():
    authors = row['AuthorNames']
    dedupedAuthors = row['AuthorNames-Deduped']
    if not (pd.isnull(authors) or pd.isnull(dedupedAuthors)):
        vispubdata.loc[index,'AuthorEditDistance'] = Levenshtein.distance(authors,dedupedAuthors)
        
vispubdata.to_csv("author-files/Vispubdata-updatedAuthors-DEBUG.csv",index =False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3088\4037987360.py in <module>
#       8     dedupedAuthors = row['AuthorNames-Deduped']
#       9     if not (pd.isnull(authors) or pd.isnull(dedupedAuthors)):
# ---> 10         vispubdata.loc[index,'AuthorEditDistance'] = Levenshtein.distance(authors,dedupedAuthors)
#      11
#      12 vispubdata.to_csv("author-files/Vispubdata-updatedAuthors-DEBUG.csv",index =False)
#
# NameError: name 'Levenshtein' is not defined

# %%
#Output a datafile of unique deduped author names
deduped_authors = []

authors = vispubdata['AuthorNames-Deduped'].dropna()

for author in authors:
    authors = author.split(';')
    for a in authors:
        deduped_authors.append(a)
    

#TODO
#Implement a check where the last name of the first author between the deduped authors and the vispubauthors are checked
#there is at least one or two rows where errors happen every year



deduped_unique_authors = list(set(deduped_authors))

#print(deduped_unique_authors)    

pd.DataFrame({'Authors':deduped_unique_authors}).to_csv('author-files/Deduped-Authors.csv',index=False)

# %% [markdown]
# Create a file for authors and paper DOIs: DedupedAuthors-Papers.csv

# %%
newVersion = pd.read_csv(currentvispubdataupdate,dtype=object,keep_default_na=False)
#newVersion = pd.read_csv("IEEE VIS papers 1990-2018 - Main dataset(6).csv",dtype=object,keep_default_na=False)


#create the papers -> author names df
papersAuthorsTemp = pd.DataFrame({'Paper DOI':newVersion['DOI'],'Author Names':newVersion['AuthorNames-Deduped']})
papersAuthors = pd.DataFrame(papersAuthorsTemp['Author Names'].str.split(';').tolist(), index=papersAuthorsTemp['Paper DOI']).stack()
papersAuthors = papersAuthors.reset_index([0, 'Paper DOI'])
papersAuthors.columns = ['Paper DOI', 'Author Names']

papersAuthors.to_csv("author-files/DedupedAuthors-Papers.csv",index=False)

papersAuthors.head()
# Out:
#                     Paper DOI      Author Names
# 0  10.1109/VISUAL.1990.146402  Alfred Inselberg
# 1  10.1109/VISUAL.1990.146402  Bernard Dimsdale
# 2  10.1109/VISUAL.1990.146386   Jeffrey LeBlanc
# 3  10.1109/VISUAL.1990.146386   Matthew O. Ward
# 4  10.1109/VISUAL.1990.146386    Norman Wittels

# %% [markdown]
# Augment the df above with information on author position

# %%
papersAuthorsPosition = papersAuthors
papersAuthorsPosition['PositionNumber'] = -1
papersAuthorsPosition['PositionCode'] = ''
papersAuthorsPosition['Affiliation'] = ''

papersAuthorsPosition.head()
lastDOI = ''
lastPosition = 0
lastindex = -1

#Warning, this assumes that the df was created in sorted order
for index, row in papersAuthorsPosition.iterrows():
    doi = row['Paper DOI']
    position = -1
    affiliation = ''
    
    allAffs = newVersion.loc[newVersion['DOI'] == doi,'AuthorAffiliation'].values[0]
    #print(allAffs)
    
    affList = allAffs.split(";")
    
    if doi != lastDOI:
        #we've reached a new paper
        position = 1
        positionCode = 'F'
        lastDOI = doi
        if len(affList) > 0:
            affiliation = affList[0]
        
        #if we're not at the very first row
        if lastindex != -1:
            #we need to update the positionCode of the last author
            papersAuthorsPosition.loc[lastindex,'PositionCode'] = 'L'
            #if it was a single author, we set them to 'F'
            if papersAuthorsPosition.loc[lastindex,'PositionNumber'] == 1:
                papersAuthorsPosition.loc[lastindex,'PositionCode'] = 'F'

    elif doi == lastDOI:
        #we're still at the same paper
        if len(affList) > lastPosition:
            affiliation = affList[lastPosition]
        position = lastPosition + 1
        positionCode = 'M'
        
        
    papersAuthorsPosition.loc[index,'PositionNumber'] = position
    papersAuthorsPosition.loc[index,'PositionCode'] = positionCode
    papersAuthorsPosition.loc[index,'Affiliation'] = affiliation
    lastindex = index
    lastPosition = position
        
        
papersAuthorsPosition.to_csv("author-files/DedupedAuthors-Papers-Position-Affiliation.csv",index=False)

papersAuthorsPosition.head(10)
# Out:
#                     Paper DOI             Author Names  PositionNumber  \
# 0  10.1109/VISUAL.1990.146402         Alfred Inselberg               1
# 1  10.1109/VISUAL.1990.146402         Bernard Dimsdale               2
# 2  10.1109/VISUAL.1990.146386          Jeffrey LeBlanc               1
# 3  10.1109/VISUAL.1990.146386          Matthew O. Ward               2
# 4  10.1109/VISUAL.1990.146386           Norman Wittels               3
# 5  10.1109/VISUAL.1990.146375          Stephen Wehrend               1
# 6  10.1109/VISUAL.1990.146375         Clayton H. Lewis               2
# 7  10.1109/VISUAL.1990.146380            Gyorgy Fekete               1
# 8  10.1109/VISUAL.1990.146377  Kalpathi R. Subramanian               1
# 9  10.1109/VISUAL.1990.146377        Donald S. Fussell               2
#
#   PositionCode                                        Affiliation
# 0            F              IBM Sci. Center, Los Angeles, CA, USA
# ...

# %% [markdown]
# ### Create the new affiliation file for cleaning

# %%
#load the previously cleaned affilation file
cleanedAffiliations = pd.read_csv("author-files/authors-affiliations-cleaned-June-2020.csv",dtype=object,keep_default_na=False)
#print(cleanedAffiliations.head())

mergedDF = papersAuthorsPosition.merge(cleanedAffiliations,how='left',left_on=['Paper DOI','Author Names'],right_on=['DOI','AuthorNames-Deduped'])
mergedDF.drop(['Year','DOI','AuthorNames-Deduped'],axis=1,inplace=True)
mergedDF.columns = ['DOI','AuthorName-Deduped','PositionNumber','PositionCode','OriginalAffiliation','CleanedAffiliation','Country']


mergedDF.to_csv('author-files/authors-affiliations-2022-toclean-withVASTconf.csv')

mergedDF.head()
# Out:
#                           DOI AuthorName-Deduped  PositionNumber PositionCode  \
# 0  10.1109/VISUAL.1990.146402   Alfred Inselberg               1            F
# 1  10.1109/VISUAL.1990.146402   Bernard Dimsdale               2            L
# 2  10.1109/VISUAL.1990.146386    Jeffrey LeBlanc               1            F
# 3  10.1109/VISUAL.1990.146386    Matthew O. Ward               2            M
# 4  10.1109/VISUAL.1990.146386     Norman Wittels               3            L
#
#                      OriginalAffiliation  \
# 0  IBM Sci. Center, Los Angeles, CA, USA
# 1  IBM Sci. Center, Los Angeles, CA, USA
# 2     Worcester Polytech. Inst., MA, USA
# 3     Worcester Polytech. Inst., MA, USA
# 4     Worcester Polytech. Inst., MA, USA
#
#                        CleanedAffiliation Country
# 0                       IBM Research, USA     USA
# 1                       IBM Research, USA     USA
# 2  Worcester Polytechnical Institute, USA     USA
# ...

# %% [markdown]
# Now create a file that finds out where changes in deduped names happened

# %%
newAuthors = pd.read_csv("DedupedAuthors-Papers-Position-Affiliation.csv",keep_default_na=False, dtype=object)
oldAuthors = pd.read_csv("DedupedAuthors-Papers-Position-2018.csv",keep_default_na=False, dtype=object)

mergedDf = newAuthors.merge(oldAuthors, how='left',left_on=['Paper DOI','PositionNumber'],right_on=['Paper DOI','PositionNumber'])
mergedDf.drop(['PositionNumber','PositionCode_x','PositionCode_y'],axis=1,inplace=True)

mergedDf.columns = ['Paper DOI','Author Name New','Author Name Old']

mergedDf['Same'] =(mergedDf['Author Name New'] == mergedDf['Author Name Old'])

        
mergedDf.to_csv("DedupedAuthors-Difference-2020-to-2018.csv",index=False)

mergedDf.head()
# Out:
#                     Paper DOI  Author Name New  Author Name Old  Same
# 0            10.0000/00000001  Randy L. Ribler  Randy L. Ribler  True
# 1            10.0000/00000001      Marc Abrams      Marc Abrams  True
# 2            10.0000/00000002     Donna J. Cox     Donna J. Cox  True
# 3  10.1109/INFVIS.1995.528680    Robert Spence    Robert Spence  True
# 4  10.1109/INFVIS.1995.528680     Lisa Tweedie     Lisa Tweedie  True

# %%
# Out:
# 12762
# 10734
#                     Paper DOI  \
# 0            10.0000/00000001
# 1            10.0000/00000002
# 2  10.1109/INFVIS.1995.528680
# 3  10.1109/INFVIS.1995.528680
# 4  10.1109/INFVIS.1995.528680
#
#                                          Affiliation
# 0
# 1
# 2  Dept. of Electr. Eng., Imperial Coll. of Sci.,...
# 3  Dept. of Electr. Eng., Imperial Coll. of Sci.,...
# 4  Dept. of Electr. Eng., Imperial Coll. of Sci.,...

# %% [markdown]
# # Old Code
# You can run the next code also if you think you want to attempt a manual dedupe of the remaining authors

# %%
un_deduped_vispubdataentries = pd.read_csv("IEEE VIS papers 1990-2018 - Main dataset(6).csv",keep_default_na=False)
deduped_vispubdataentries = pd.read_csv("Deduped-Authors.csv")

print(un_deduped_vispubdataentries.info())
print(deduped_vispubdataentries.info())

deduped_authors = deduped_vispubdataentries["Authors"].tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Conference                     3237 non-null   object
#  1   Year                           3237 non-null   int64
#  2   Title                          3237 non-null   object
#  3   DOI                            3237 non-null   object
#  4   Link                           3237 non-null   object
#  5   FirstPage                      3237 non-null   object
#  6   LastPage                       3237 non-null   object
#  7   PaperType                      3237 non-null   object
#  8   Abstract                       3237 non-null   object
#  9   AuthorNames-Deduped            3237 non-null   object
#  10  AuthorNames                    3237 non-null   object
#  11  AuthorAffiliation              3237 non-null   object
# ...

# %%
non_deduped_authors = []

authors = un_deduped_vispubdataentries['AuthorNames'].dropna()


for author in authors:
    authors = author.split(';')
    for a in authors:
        non_deduped_authors.append(a)
    
non_deduped_unique_authors = list(set(non_deduped_authors))

print("Authors not found in the deduped set")

for author in non_deduped_unique_authors:
    if not author in deduped_authors:
        print(author)
# Out:
# Authors not found in the deduped set
#
# D. Jen
# M.J. Allison
# N. Volkow
# H.W. Park
# Bernice Rogowitz
# J. Sahner
# S. Maxwell
# M. Marwah
# D. Merhof
# D.C. Glaser
# Mária Tekušová
# A. Goel
# Klaus Hinrichs
# T. Schreck
# Karl Proctor
# T. van Walsum
# Y. Levy
# P.M.A. van Ooijen
# M.J. Avalos
# Yalong Yang
# E. Boring
# X. Gu
# M. Sips
# M. Williams
# Florencia Gargiulo
# R. Mackenzie
# Niklas Roeber
# Duen Horng Polo Chau
# A.J. Kolojechick
# O. Omoteso
# Margo Seltzer
# Jarke van Wijk
# L. Carmel
# N. Max
# R. Yagel
# J.M. Favre
# C. Starr
# P. Cignoni
# J. Bermudez
# Dominik Morent
# W. Ribarsky
# J. Hensley
# Clemens W.G.M. Lowik
# N. Shareef
# E. Deines
# P. Hogan
# M.M. Loughlin
# F. Ledermann
# D. Darmofal
# H. Kruger
# J. Haber
# F. Ponchio
# Bing Wang
# J. Gonser
# M. Ross
# M. Kraus
# M.H. Brown
# Matthew Ward
# Benjamin Hoferlin
# J. Assa
# Tobias Hollerer
# E.H. Theil
# P.J. Smith
# L. Ulitsky
# T. Welsh
# Ming Lin
# Z. Konyha
# D. Lu
# Beverly E Faulkner-Jones
# ...

# %% [markdown]
# I don't recommend to do this unless it's a small number <20 or so
