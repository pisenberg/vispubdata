# %%
import pandas as pd
import json
import re
import pickle

#these appendices allow to distinguish the matching for the vis papers and the journal papers presented at vis

#updateAppendix = 'vis-papers'
#updateFile = "../vispubdata-update/results/vispubdata-update.csv"

#since there is some inspection you need to do per file, comment the file you are currently working on

#updateAppendix = 'journal-papers'
#updateFile = "../vispubdata-update/results/vispubdata-update-journals.csv"

updateAppendix = 'vis-papers'
updateFile = '../vispubdata-update/results/vispubdata-update.csv'

# %% [markdown]
# ### Load paper matching data

# %%
# Exact match (doi or title) from the first scan
first = pd.read_csv('./results/exact_matching'+updateAppendix+'.csv')
first.head()
# Out:
#                    vispub_doi                 aminer_id method
# 0  10.1109/visual.1999.809927  539087f820f70186a0d72a84    doi
# 1   10.1109/vast.2007.4388993  5390a45620f70186a0e733d1    doi
# 2   10.1109/tvcg.2017.2744479  59ae0cda0cf284510fa8b411    doi
# 3   10.1109/tvcg.2020.3030456  5f7c371791e0117ac2a788a1    doi
# 4  10.1109/visual.1996.568151  539087dd20f70186a0d62acb    doi

# %%
# Verified match from the second scan
second = pd.read_csv('./results/candidate_papers'+updateAppendix+'.csv')[['vispub_doi', 'aminer_id']]
second['method'] = 'string matching'
second.head()
# Out:
#                    vispub_doi                 aminer_id           method
# 0   10.1109/vast.2007.4389035  5390a45620f70186a0e733e6  string matching
# 1   10.1109/vast.2007.4389020  5390a45620f70186a0e733eb  string matching
# 2       10.1109/visual.2004.3  5390979920f70186a0e0053d  string matching
# 3  10.1109/visual.1999.809874  539087eb20f70186a0d6c09e  string matching
# 4   10.1109/vast.2011.6102460  53e9af53b7602d9703995feb  string matching

# %%
matches = pd.concat([first, second])
matches
# Out:
#                      vispub_doi                 aminer_id           method
# 0    10.1109/visual.1999.809927  539087f820f70186a0d72a84              doi
# 1     10.1109/vast.2007.4388993  5390a45620f70186a0e733d1              doi
# 2     10.1109/tvcg.2017.2744479  59ae0cda0cf284510fa8b411              doi
# 3     10.1109/tvcg.2020.3030456  5f7c371791e0117ac2a788a1              doi
# 4    10.1109/visual.1996.568151  539087dd20f70186a0d62acb              doi
# ..                          ...                       ...              ...
# 12  10.1109/infvis.2003.1249022  5390b5c620f70186a0f08b38  string matching
# 13  10.1109/visual.2003.1250385  573696726e3b12023e57ecf7  string matching
# 14  10.1109/infvis.2002.1173151  5390958920f70186a0dee863  string matching
# 15   10.1109/infvis.2001.963288  5390958920f70186a0dedfc4  string matching
# 16   10.1109/visual.1992.235205  5390962020f70186a0df3df2  string matching
#
# [3489 rows x 3 columns]

# %%
ids = list(matches['aminer_id'])
dois = matches.set_index('aminer_id')['vispub_doi'].to_dict()

# %%
# Check the papers that has multiple aminer_id
m = matches.groupby('vispub_doi').agg({'aminer_id': 'count'})
m[m['aminer_id'] > 1]
# Out:
#                             aminer_id
# vispub_doi
# 10.1109/tvcg.2007.70582             2
# 10.1109/tvcg.2020.3030412           2
# 10.1109/tvcg.2022.3209367           2
# 10.1109/tvcg.2022.3209444           2
# 10.1109/tvcg.2022.3209455           2
# 10.1109/tvcg.2023.3327187           2
# 10.1109/vast.2011.6102474           2
# 10.1109/visual.1994.346290          2
# 10.1109/visual.1994.346291          2
# 10.1109/visual.2000.885720          2

# %% [markdown]
# ### Get Aminer paper details

# %%
# %%time
papers = dict()
count, match_ids = 0, 0
with open("./data/DBLP-Citation-network-V18.jsonl", encoding="utf8") as infile:
    for line in infile:
        line = line.strip().strip(',').strip("]'")
        if line[0] != '{':
            continue
        paper = json.loads(line)
        lower = re.sub(r'[^\w]', '', str(paper['title']).lower())
        
        # First, try to match by paper DOI
        if paper['id'] in ids:
            papers[paper['id']] = paper
            match_ids += 1
            
        count += 1 
        if (count % 1000000 == 0):
            print(count, match_ids)
    print(count, match_ids)
# Out:
# 1000000 523
# 2000000 1060
# 3000000 1539
# 4000000 2099
# 5000000 2611
# 6000000 3108
# 6729828 3486
# CPU times: total: 9min 58s
# Wall time: 10min 3s

# %%
len(ids), len(papers)
# Out:
# (3489, 3486)

# %%
with open(f'results/aminer_match_papers_{updateAppendix}.p', 'wb') as fp:
    pickle.dump(papers, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Load Aminer paper details data

# %%
#with open(f'results/aminer_match_papers_{updateAppendix}.p', 'rb') as fp:
#    papers = pickle.load(fp)
#len(papers)

# %%
# Check the detail of papers with multiple Aminer ids
#papers['558a4774e4b0b32fcb35e104']

# %%
#papers['635bcab890e50fcafd33d13b']

# %% [markdown]
# Internal references

# %%
df = pd.read_csv(updateFile, keep_default_na=False)
df['doi'] = df["DOI"].apply(lambda x: str(x).lower())
years = df.set_index('DOI')['Year'].to_dict()

# %%
cites = list()
years = dict()
for key, value in papers.items():
    years[key] = value['year']
    if 'references' in value:
        for i in value['references']:
            cites.append([key, value['year'], i])
cites = pd.DataFrame(cites, columns=['paper', 'paper_year', 'reference'])

# %%
cites
# Out:
#                           paper  paper_year                 reference
# 0      539087f820f70186a0d72a84        1999  539087ef20f70186a0d6d63e
# 1      539087f820f70186a0d72a84        1999  539087f320f70186a0d6ebe6
# 2      539087f820f70186a0d72a84        1999  53e9b931b7602d970451f59f
# 3      539087f820f70186a0d72a84        1999  539087e720f70186a0d69150
# 4      539087f820f70186a0d72a84        1999  53e9b61bb7602d9704173f3f
# ...                         ...         ...                       ...
# 69848  58437713ac44360f1082cc08        2016  53e9b409b7602d9703eff385
# 69849  58437713ac44360f1082cc08        2016  573696656e3b12023e5717b7
# 69850  669dbc8001d2a3fbfca4232d        2024  573696796e3b12023e5849d6
# 69851  669dbc8001d2a3fbfca4232d        2024  5390be6620f70186a0f4bb8a
# 69852  669dbc8001d2a3fbfca4232d        2024  5390b20120f70186a0ee5043
#
# [69853 rows x 3 columns]

# %%
# Filter only internal citations
cites = cites[cites['reference'].isin(ids)].copy()
cites['reference_year'] = cites['reference'].replace(years)

# %%
# Remove self citation
cites = cites[cites['paper'] != cites['reference']]

# %%
# Filter only citations that come after the paper year
cites[cites['reference_year'] > cites['paper_year']]
# Out:
#                           paper  paper_year                 reference  \
# 608    558b658b84ae84d265c3250e        2012  53e9a627b7602d9702f54d44
# 2283   610cad6e5244ab9dcb1b41b6        2021  5687debc0cf2afdcd165faae
# 2382   55503f9045ce0a409eb2ebf8        2014  5550451945ce0a409eb539a7
# 5787   53e9a711b7602d9703048203        2012  53e9a627b7602d9702f54d44
# 6446   5390a45620f70186a0e733f1        2007  53e9b890b7602d970446206c
# 10465  6125b69b5244ab9dcb41ce46        2021  6334267f90e50fcafd6a4a0d
# 68691  59ae0cdb0cf284510fa8b438        2004  55503f9145ce0a409eb2eca6
# 68692  59ae0cdb0cf284510fa8b438        2004  53e9a711b7602d9703048203
# 68696  59ae0cdb0cf284510fa8b438        2004  58437713ac44360f1082cc1c
# 68698  59ae0cdb0cf284510fa8b438        2004  558c147e84ae6766fdf0ee24
# 68700  59ae0cdb0cf284510fa8b438        2004  5390b20120f70186a0ee5048
# 68701  59ae0cdb0cf284510fa8b438        2004  5390a6d920f70186a0e87dcc
# 68703  59ae0cdb0cf284510fa8b438        2004  557c48ff08b02739a5ca33a6
# 68704  59ae0cdb0cf284510fa8b438        2004  5390be6620f70186a0f4bbc4
#
#       reference_year
# 608             2014
# 2283            2022
# 2382            2016
# 5787            2014
# 6446            2008
# 10465           2022
# 10497           2022
# 12579           2022
# 13781           2021
# 16279           2020
# 19133           2010
# 19204           2011
# 19210           2012
# 19213           2015
# 19215           2015
# 19216           2011
# 19217           2014
# 19221           2011
# 19224           2014
# 19226           2012
# 19227           2013
# 19228           2014
# 26558           2018
# 27756           2015
# 28300           2018
# 29049           2020
# 29903           2014
# 30119           2016
# 33792           2018
# 34095           2010
# 34101           2010
# 35261           2014
# 43167           2018
# 44587           2024
# 47774           2018
# 47841           2020
# 49596           2022
# 49741           2020
# 51152           2014
# 54708           2016
# 58158           2016
# 58981           2008
# 65391           2008
# 66854           2023
# 67799           2010
# 68685           2017
# 68688           2008
# 68691           2014
# 68692           2012
# 68696           2016
# 68698           2014
# 68700           2011
# 68701           2009
# 68703           2014
# 68704           2013

# %%
# Replace with vispubdata DOIs
cites = cites.replace(dois)

cites['paper_year'] = cites['paper'].copy().replace(years)
cites['reference_year'] = cites['reference'].copy().replace(years)

# %%
# Remove citation in the future
cites = cites[cites['reference_year'] <= cites['paper_year']]

# %%
c = cites.groupby('paper').agg({'reference': 'unique'}).reset_index()
c['reference'] = c['reference'].apply(lambda x: ';'.join(x))
c = c.set_index('paper')['reference'].to_dict()

# %% [markdown]
# ### Merge into vispubdata dataset

# %%
df = pd.read_csv(updateFile, keep_default_na=False)

# %%
# Clear old citation count column
df['AminerCitationCount'] = None

# %%
count = 0
for index, row in df.iterrows():
    if not row['DOI'] in list(matches['vispub_doi']):
        continue
    
    # Citation count
    m_ids = list(matches.loc[matches['vispub_doi'] == row['DOI'], 'aminer_id'])
    n_cites = max([papers[x]['n_citation'] for x in m_ids])
    df.loc[index, 'AminerCitationCount'] = n_cites
    
    # Internal references
    #if row['DOI'] in c:
    #    df.loc[index, 'internal_references'] = c[row['DOI']]
    
    count += 1

# %%
df
# Out:
#      Conference  Year                                              Title  \
# 0           Vis  2024  Interactive Design-of-Experiments: Optimizing ...
# 1           Vis  2024  Towards Dataset-Scale and Feature-Oriented Eva...
# 2           Vis  2024  KNowNEt:Guided Health Information Seeking from...
# 3           Vis  2024  VisEval: A Benchmark for Data Visualization in...
# 4           Vis  2024  PUREsuggest: Citation-Based Literature Search ...
# ...         ...   ...                                                ...
# 4003        Vis  2025  Perceiving Slope and Acceleration: Evidence fo...
# 4004        Vis  2025  The Impact of Visual Segmentation on Lexical W...
# 4005        Vis  2025  OW-CLIP: Data-Efficient Visual Supervision for...
# 4006        Vis  2025  Investigating the Effects of Augmented Reality...
# 4007        Vis  2025                    Uncertainty-Aware PCA Revisited
#
#                             DOI                                         Link  \
# 0     10.1109/tvcg.2024.3456356  http://dx.doi.org/10.1109/TVCG.2024.3456356
# 1     10.1109/tvcg.2024.3456398  http://dx.doi.org/10.1109/TVCG.2024.3456398
# 2     10.1109/tvcg.2024.3456364  http://dx.doi.org/10.1109/TVCG.2024.3456364
# 3     10.1109/tvcg.2024.3456320  http://dx.doi.org/10.1109/TVCG.2024.3456320
# 4     10.1109/tvcg.2024.3456199  http://dx.doi.org/10.1109/TVCG.2024.3456199
# ...                         ...                                          ...
# 4003  10.1109/tvcg.2025.3633835  http://dx.doi.org/10.1109/TVCG.2025.3633835
# 4004  10.1109/tvcg.2025.3634641  http://dx.doi.org/10.1109/TVCG.2025.3634641
# 4005  10.1109/tvcg.2025.3633870  http://dx.doi.org/10.1109/TVCG.2025.3633870
# 4006  10.1109/tvcg.2025.3634786  http://dx.doi.org/10.1109/TVCG.2025.3634786
# 4007  10.1109/tvcg.2025.3633868  http://dx.doi.org/10.1109/TVCG.2025.3633868
#
#      FirstPage LastPage PaperType  \
# 0           44       53         J
# 1          481      491         J
# 2          547      557         J
# 3         1301     1311         J
# 4          316      326         J
# ...        ...      ...       ...
# 4003       221      231         J
# 4004       857      867         J
# 4005        68       78         J
# 4006      1087     1097         J
# 4007       363      373         J
#
#                                                Abstract  \
# 0     The optimization of cooling systems is importa...
# 1     Recent advancements in Large Language Models (...
# 2     The increasing reliance on Large Language Mode...
# 3     Translating natural language to visualization ...
# 4     Citations allow quickly identifying related re...
# ...                                                 ...
# 4003  Sonification offers a non-visual way to unders...
# 4004  When a reader encounters a word in English, th...
# 4005  Open-world object detection (OWOD) extends tra...
# 4006  Augmented reality (AR) has increasingly been u...
# 4007  Principal Component Analysis (PCA) is perhaps ...
#
#                                     AuthorNames-Deduped  ...  \
# 0     Rainer Splechtna;Majid Behravan;Mario Jelovic;...  ...
# 1     Sam Yu-Te Lee;Aryaman Bahukhandi;Dongyu Liu;Kw...  ...
# 2     Youfu Yan;Yu Hou;Yongkang Xiao;Rui Zhang 0028;...  ...
# 3     Nan Chen;Yuge Zhang;Jiahang Xu;Kan Ren;Yuqing ...  ...
# 4                                      Fabian Beck 0001  ...
# ...                                                 ...  ...
# 4003  Danyang Fan;Walker Smith;Takako Fujioka;Chris ...  ...
# 4004   Matthew Termuende;Kevin Larson;Miguel A. Nacenta  ...
# 4005  Junwen Duan;Wei Xue;Ziyao Kang;Shixia Liu;Jiaz...  ...
# 4006  Aymeric Ferron;Ambre Assor;Pierre Dragicevic;Y...  ...
# 4007  Lukas Friesecke;Christian Braune;Christian Rös...  ...
#
#      PubsCited_CrossRef Downloads_Xplore Award GraphicsReplicabilityStamp  \
# 0                    29              519
# 1                    65             1256
# 2                    60             1892    HM
# 3                    75             2232    BP
# 4                    62              515
# ...                 ...              ...   ...                        ...
# 4003                 85              175
# 4004                 71              154
# 4005                 63              363
# 4006                 81              217
# 4007                 42              256
#
#      Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0
# 1
# 2
# 3
# 4
# ...          ...         ...         ...         ...         ...         ...
# 4003
# 4004
# 4005
# 4006
# 4007
#
# [4008 rows x 26 columns]

# %%
df.to_csv(updateFile + '-aminer.csv', index=False)
