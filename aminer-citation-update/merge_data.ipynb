# %%
import pandas as pd
import json
import re
import pickle

#these appendices allow to distinguish the matching for the vis papers and the journal papers presented at vis

#updateAppendix = 'vis-papers'
#updateFile = "../vispubdata-update/results/vispubdata-update.csv"

#since there is some inspection you need to do per file, comment the file you are currently working on

updateAppendix = 'journal-papers'
updateFile = "../vispubdata-update/results/vispubdata-update-journals.csv"

# %% [markdown]
# ### Load paper matching data

# %%
# Exact match (doi or title) from the first scan
first = pd.read_csv('./results/exact_matching'+updateAppendix+'.csv')
first.head()
# Out:
#               vispub_doi                 aminer_id method
# 0  10.1109/tvcg.2010.227  53e997f8b7602d9701ffe7c8    doi
# 1  10.1109/tvcg.2011.155  53e997fcb7602d9702007dcd    doi
# 2  10.1109/tvcg.2010.259  53e9985fb7602d9702097c56    doi
# 3  10.1109/tvcg.2010.111  53e99876b7602d97020af740    doi
# 4   10.1109/tvcg.2012.93  53e999a6b7602d97021ec04f    doi

# %%
# Verified match from the second scan
second = pd.read_csv('./results/candidate_papers'+updateAppendix+'.csv')[['vispub_doi', 'aminer_id']]
second['method'] = 'string matching'
second.head()
# Out:
#                   vispub_doi                 aminer_id           method
# 0  10.1109/tvcg.2022.3219232  6257c5c15aee126c0f469dbb  string matching
# 1  10.1109/tvcg.2022.3223399  5d0cb0c68607575390002c84  string matching
# 2  10.1109/tvcg.2023.3238008  557dbb12d19faf961d1635f2  string matching
# 3  10.1109/tvcg.2023.3261981  53e99b9bb7602d9702443b20  string matching
# 4  10.1109/tvcg.2022.3226463  53e9a32eb7602d9702c3a224  string matching

# %%
matches = pd.concat([first, second])
matches
# Out:
#                     vispub_doi                 aminer_id           method
# 0        10.1109/tvcg.2010.227  53e997f8b7602d9701ffe7c8              doi
# 1        10.1109/tvcg.2011.155  53e997fcb7602d9702007dcd              doi
# 2        10.1109/tvcg.2010.259  53e9985fb7602d9702097c56              doi
# 3        10.1109/tvcg.2010.111  53e99876b7602d97020af740              doi
# 4         10.1109/tvcg.2012.93  53e999a6b7602d97021ec04f              doi
# ..                         ...                       ...              ...
# 176  10.1109/tvcg.2024.3372104  58437789ac44360f10843bd0  string matching
# 177  10.1109/tvcg.2023.3333356  5b8c9eea17c44af36f8b008d  string matching
# 178  10.1109/tvcg.2023.3336588  5c90330c4895d9cbc679f62c  string matching
# 179  10.1109/tvcg.2022.3229017  53e99991b7602d97021d67aa  string matching
# 180  10.1109/tvcg.2023.3324851  53e9b17ab7602d9703c04b24  string matching
#
# [634 rows x 3 columns]

# %%
ids = list(matches['aminer_id'])
dois = matches.set_index('aminer_id')['vispub_doi'].to_dict()

# %%
# Check the papers that has multiple aminer_id
m = matches.groupby('vispub_doi').agg({'aminer_id': 'count'})
m[m['aminer_id'] > 1]
# Out:
#                            aminer_id
# vispub_doi
# 10.1109/tvcg.2015.2440259          2
# 10.1109/tvcg.2019.2920639          2
# 10.1109/tvcg.2020.2969185          2
# 10.1109/tvcg.2021.3106142          2

# %%
matches[matches['vispub_doi'] == '10.1109/infvis.1995.528685']
# Out:
# Empty DataFrame
# Columns: [vispub_doi, aminer_id, method]
# Index: []

# %% [markdown]
# ### Get Aminer paper details

# %%
# %%time
papers = dict()
count, match_ids = 0, 0
with open("./data/dblp_v14.json", encoding="utf8") as infile:
    for line in infile:
        line = line.strip().strip(',').strip("]'")
        if line[0] != '{':
            continue
        paper = json.loads(line)
        lower = re.sub(r'[^\w]', '', str(paper['title']).lower())
        
        # First, try to match by paper DOI
        if paper['id'] in ids:
            papers[paper['id']] = paper
            match_ids += 1
            
        count += 1 
        if (count % 1000000 == 0):
            print(count, match_ids)
    print(count, match_ids)
# Out:
# 1000000 57
# 2000000 104
# 3000000 203
# 4000000 387
# 5000000 602
# 5259858 630
# CPU times: total: 4min 44s
# Wall time: 4min 47s

# %%
len(ids), len(papers)
# Out:
# (634, 630)

# %%
with open('results/aminer_match_papers.p', 'wb') as fp:
    pickle.dump(papers, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Load Aminer paper details data

# %%
with open('results/aminer_match_papers.p', 'rb') as fp:
    papers = pickle.load(fp)
len(papers)
# Out:
# 630

# %%
# Check the detail of papers with multiple Aminer ids
#papers['558a4774e4b0b32fcb35e104']

# %%
#papers['635bcab890e50fcafd33d13b']

# %% [markdown]
# Internal references

# %%
df = pd.read_csv(updateFile, keep_default_na=False)
df['doi'] = df["DOI"].apply(lambda x: str(x).lower())
years = df.set_index('DOI')['Year'].to_dict()

# %%
cites = list()
years = dict()
for key, value in papers.items():
    years[key] = value['year']
    if 'references' in value:
        for i in value['references']:
            cites.append([key, value['year'], i])
cites = pd.DataFrame(cites, columns=['paper', 'paper_year', 'reference'])

# %%
cites
# Out:
#                           paper  paper_year                 reference
# 0      53e997f8b7602d9701ffe7c8        2011  557dfd8af6678c77ea21f101
# 1      53e997f8b7602d9701ffe7c8        2011  53e99e61b7602d9702723b79
# 2      53e997f8b7602d9701ffe7c8        2011  53e9a4ddb7602d9702dfe202
# 3      53e997f8b7602d9701ffe7c8        2011  53e9a9b8b7602d97033193b5
# 4      53e997f8b7602d9701ffe7c8        2011  53e9af00b7602d9703936683
# ...                         ...         ...                       ...
# 10878  633c109b90e50fcafdc257ca        2018  59ae0cda0cf284510fa8b419
# 10879  633c109b90e50fcafdc257ca        2018  58437713ac44360f1082cc07
# 10880  633c109b90e50fcafdc257ca        2018  53e99b86b7602d970242afc8
# 10881  634b728290e50fcafdd0565e        2022  5dcfcb70df1a9c0c41566335
# 10882  634b728290e50fcafdd0565e        2022  6173f1c391e0118698c04ad8
#
# [10883 rows x 3 columns]

# %%
# Filter only internal citations
cites = cites[cites['reference'].isin(ids)].copy()
cites['reference_year'] = cites['reference'].replace(years)
# Out:
# C:\Users\petra\AppData\Local\Temp\ipykernel_38988\3422505603.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cites['reference_year'] = cites['reference'].replace(years)

# %%
# Remove self citation
cites = cites[cites['paper'] != cites['reference']]

# %%
# Filter only citations that come after the paper year
cites[cites['reference_year'] > cites['paper_year']]
# Out:
# Empty DataFrame
# Columns: [paper, paper_year, reference, reference_year]
# Index: []

# %%
# Replace with vispubdata DOIs
cites = cites.replace(dois)

cites['paper_year'] = cites['paper'].copy().replace(years)
cites['reference_year'] = cites['reference'].copy().replace(years)

# %%
# Remove citation in the future
cites = cites[cites['reference_year'] <= cites['paper_year']]

# %%
c = cites.groupby('paper').agg({'reference': 'unique'}).reset_index()
c['reference'] = c['reference'].apply(lambda x: ';'.join(x))
c = c.set_index('paper')['reference'].to_dict()

# %% [markdown]
# ### Merge into vispubdata dataset

# %%
df = pd.read_csv(updateFile, keep_default_na=False)

# %%
count = 0
for index, row in df.iterrows():
    if not row['DOI'] in list(matches['vispub_doi']):
        continue
    
    # Citation count
    m_ids = list(matches.loc[matches['vispub_doi'] == row['DOI'], 'aminer_id'])
    n_cites = max([papers[x]['n_citation'] for x in m_ids])
    df.loc[index, 'AminerCitationCount'] = n_cites
    
    # Internal references
    #if row['DOI'] in c:
    #    df.loc[index, 'internal_references'] = c[row['DOI']]
    
    count += 1

# %%
df
# Out:
#     Journal  Year                                              Title  \
# 0      TVCG  2024  Visual Exploration of Machine Learning Model B...
# 1      TVCG  2024  DMT-EV: An Explainable Deep Network for Dimens...
# 2      TVCG  2024  Discrete Morse Sandwich: Fast Computation of P...
# 3      TVCG  2024  Parallel Computation of Piecewise Linear Morse...
# 4      TVCG  2024  The Risks of Ranking: Revisiting Graphical Per...
# ..      ...   ...                                                ...
# 625    TVCG  2025  VisTellAR: Embedding Data Visualization to Sho...
# 626    TVCG  2024  SenseMap: Urban Performance Visualization and ...
# 627    TVCG  2024  Memory Recall for Data Visualizations in Mixed...
# 628    TVCG  2024  V-Mail: 3D-Enabled Correspondence About Spatia...
# 629    TVCG  2024  Interpreting High-Dimensional Projections With...
#
#                            DOI                                         Link  \
# 0    10.1109/tvcg.2022.3219232  http://dx.doi.org/10.1109/TVCG.2022.3219232
# 1    10.1109/tvcg.2022.3223399  http://dx.doi.org/10.1109/TVCG.2022.3223399
# 2    10.1109/tvcg.2023.3238008  http://dx.doi.org/10.1109/TVCG.2023.3238008
# 3    10.1109/tvcg.2023.3261981  http://dx.doi.org/10.1109/TVCG.2023.3261981
# 4    10.1109/tvcg.2022.3226463  http://dx.doi.org/10.1109/TVCG.2022.3226463
# ..                         ...                                          ...
# 625  10.1109/tvcg.2024.3372104  http://dx.doi.org/10.1109/TVCG.2024.3372104
# 626  10.1109/tvcg.2023.3333356  http://dx.doi.org/10.1109/TVCG.2023.3333356
# 627  10.1109/tvcg.2023.3336588  http://dx.doi.org/10.1109/TVCG.2023.3336588
# 628  10.1109/tvcg.2022.3229017  http://dx.doi.org/10.1109/TVCG.2022.3229017
# 629  10.1109/tvcg.2023.3324851  http://dx.doi.org/10.1109/TVCG.2023.3324851
#
#      FirstPage  LastPage PaperType  \
# 0         1470      1488         J
# 1         1710      1727         J
# 2         1897      1915         J
# 3         1942      1955         J
# 4         1756      1771         J
# ..         ...       ...       ...
# 625       1862      1874         J
# 626       6275      6290         J
# 627       6691      6706         J
# 628       1853      1867         J
# 629       6038      6055         J
#
#                                               Abstract  \
# 0    One of the potential solutions for model inter...
# 1    Dimension reduction (DR) is commonly utilized ...
# 2    This paper introduces an efficient algorithm f...
# 3    This article presents a well-scaling parallel ...
# 4    Graphical perception studies typically measure...
# ..                                                 ...
# 625  With the rise of short-form video platforms an...
# 626  As urban populations grow, effectively accessi...
# 627  This article explores how the ability to recal...
# 628  We present V-Mail, a framework of cross-platfo...
# 629  Dimensionality reduction (DR) algorithms are d...
#
#                                    AuthorNames-Deduped  \
# 0      Jun Yuan;Brian Barr;Kyle Overton;Enrico Bertini
# 1    Zelin Zang;Shenghui Cheng;Hanchen Xia;Liangyu ...
# 2             Pierre Guillou;Jules Vidal;Julien Tierny
# 3    Robin G. C. Maack;Jonas Lukasczyk;Julien Tiern...
# 4    Russell Davis;Xiaoying Pu;Yiren Ding;Brian D. ...
# ..                                                 ...
# 625  Wai Tong;Kento Shigyo;Linping Yuan;Mingming Fa...
# 626  Juntong Chen;Qiaoyun Huang;Changbo Wang;Chenhu...
# 627  Christophe Hurter;Bernice E. Rogowitz;Guillaum...
# 628  Jung Who Nam;Tobias Isenberg 0001;Daniel F. Keefe
# 629  Yang Zhang;Jisheng Liu;Chufan Lai;Yuan Zhou 00...
#
#                                            AuthorNames  \
# 0      Jun Yuan;Brian Barr;Kyle Overton;Enrico Bertini
# 1    Zelin Zang;Shenghui Cheng;Hanchen Xia;Liangyu ...
# 2             Pierre Guillou;Jules Vidal;Julien Tierny
# 3    Robin G. C. Maack;Jonas Lukasczyk;Julien Tiern...
# 4    Russell Davis;Xiaoying Pu;Yiren Ding;Brian D. ...
# ..                                                 ...
# 625  Wai Tong;Kento Shigyo;Lin-Ping Yuan;Mingming F...
# 626  Juntong Chen;Qiaoyun Huang;Changbo Wang;Chenhu...
# 627  Christophe Hurter;Bernice Rogowitz;Guillaume T...
# 628       Jung Who Nam;Tobias Isenberg;Daniel F. Keefe
# 629  Yang Zhang;Jisheng Liu;Chufan Lai;Yuan Zhou;Si...
#
#                                      AuthorAffiliation  \
# 0    New York University, New York, NY, USA;Capital...
# 1    AI Division, School of Engineering, Westlake U...
# 2    CNRS and Sorbonne Université, Paris, France;CN...
# 3    RPTU Kaiserslautern-Landau, Kaiserslautern, Ge...
# 4    Worcester Polytechnic Institute, Worcester, MA...
# ..                                                 ...
# 625  School of Performance, Visualization and Fine ...
# 626  School of Computer Science and Technology, Eas...
# 627  ENAC, Université de Toulouse, Toulouse, France...
# 628  University of Minnesota, Minneapolis, MN, USA;...
# 629  School of Data Science, Fudan University, Shan...
#
#                                     InternalReferences  \
# 0    10.1109/vast.2011.6102453;10.1109/tvcg.2018.28...
# 1    10.1109/tvcg.2020.2986996;10.1109/tvcg.2015.24...
# 2    10.1109/tvcg.2017.2743980;10.1109/visual.2004....
# 3    10.1109/tvcg.2021.3114819;10.1109/tvcg.2006.18...
# 4    10.1109/tvcg.2018.2865240;10.1109/tvcg.2015.24...
# ..                                                 ...
# 625  10.1109/tvcg.2014.2359887;10.1109/mcg.2015.51;...
# 626  10.1109/tvcg.2021.3114762;10.1109/tvcg.2019.29...
# 627  10.1109/tvcg.2013.234;10.1109/tvcg.2015.246773...
# 628  10.1109/visual.2001.964560;10.1109/tvcg.2017.2...
# 629  10.1109/tvcg.2013.153;10.1109/tvcg.2018.284673...
#
#                                         AuthorKeywords AminerCitationCount  \
# 0    Visualization,rule set,,surrogate model,model ...                   2
# 1    Dimension reduction,explainability of DR model...                   6
# 2    discrete Morse theory,persistence diagrams,,sc...                  92
# 3    Morse-smale complex,segmentation,,topology,vis...                  17
# 4    Visualization,graphical perception,,individual...                 104
# ..                                                 ...                 ...
# 625  Personal data,augmented reality,data visualiza...                   3
# 626  Density map,point of interest,semantic textual...                   7
# 627  Data visualisation,recall,virtual reality,mixe...                   1
# 628  Communication,human-computer interaction,immer...                   1
# 629  Dimensional reduction,interactive visual explo...                  12
#
#      CitationCount_CrossRef  PubsCited_CrossRef  Downloads_Xplore Award  \
# 0                         4                  51               603
# 1                         8                  56              1957
# 2                         8                 103               314
# 3                         3                  72               744
# 4                         7                  70               644
# ..                      ...                 ...               ...   ...
# 625                       1                  55               433
# 626                       4                  80               729
# 627                       0                  69               699
# 628                       0                  43               625
# 629                       0                  52               399
#
#     GraphicsReplicabilityStamp
# 0
# 1
# 2                            X
# 3                            X
# 4
# ..                         ...
# 625
# 626
# 627
# 628                          X
# 629
#
# [630 rows x 20 columns]

# %%
#df.to_csv('results/vispubdata_citation.csv', index=False)

# %%
df.to_csv(updateFile, index=False)
