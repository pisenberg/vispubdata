# %%
import pandas as pd
import json
import re
import pickle

# %% [markdown]
# ### Load paper matching data

# %%
# Exact match (doi or title) from the first scan
first = pd.read_csv('results/exact_matching.csv')
first.head()
# Out:
#                    vispub_doi                 aminer_id method
# 0  10.1109/visual.1993.398878  53e9a819b7602d970315ddb4    doi
# 1  10.1109/visual.1990.146414  53e9b3fdb7602d9703eee319    doi
# 2  10.1109/visual.1990.146412  53e9b6afb7602d970422d945    doi
# 3  10.1109/visual.1993.398863  53e9be57b7602d9704b1803a    doi
# 4      10.1109/infvis.2004.39  53e9978db7602d9701f50690  title

# %%
# Verified match from the second scan
second = pd.read_csv('results/candidate_papers.csv')[['vispub_doi', 'aminer_id']]
second['method'] = 'string matching'
second.head()
# Out:
#                     vispub_doi                 aminer_id           method
# 0  10.1109/visual.2003.1250426  599c7eff601a182cd28e1385  string matching
# 1   10.1109/visual.1997.663919  53e99acab7602d970234ddd8  string matching
# 2   10.1109/visual.1997.663928  53e9bc05b7602d970486805b  string matching
# 3   10.1109/visual.2000.885740  53e9adffb7602d9703806035  string matching
# 4   10.1109/visual.1997.663922  53e9b4e9b7602d9704014dba  string matching

# %%
matches = pd.concat([first, second])
matches
# Out:
#                     vispub_doi                 aminer_id           method
# 0   10.1109/visual.1993.398878  53e9a819b7602d970315ddb4              doi
# 1   10.1109/visual.1990.146414  53e9b3fdb7602d9703eee319              doi
# 2   10.1109/visual.1990.146412  53e9b6afb7602d970422d945              doi
# 3   10.1109/visual.1993.398863  53e9be57b7602d9704b1803a              doi
# 4       10.1109/infvis.2004.39  53e9978db7602d9701f50690            title
# ..                         ...                       ...              ...
# 50  10.1109/visual.1992.235174  53e9b408b7602d9703efa9df  string matching
# 51  10.1109/visual.1994.346291  53e9ab20b7602d97034ab8e7  string matching
# 52  10.1109/visual.1992.235188  53e9a291b7602d9702b97808  string matching
# 53  10.1109/visual.1992.235179  53e9b829b7602d97043e3e2f  string matching
# 54  10.1109/visual.1991.175834  53e9b692b7602d97042017ab  string matching
#
# [3621 rows x 3 columns]

# %%
ids = list(matches['aminer_id'])
dois = matches.set_index('aminer_id')['vispub_doi'].to_dict()

# %%
# Check the papers that has multiple aminer_id
m = matches.groupby('vispub_doi').agg({'aminer_id': 'count'})
m[m['aminer_id'] > 1]
# Out:
#                               aminer_id
# vispub_doi
# 10.0000/00000001                      2
# 10.1109/infvis.1995.528685            2
# 10.1109/infvis.1995.528687            2
# 10.1109/infvis.1997.636761            2
# 10.1109/infvis.1997.636790            2
# ...                                 ...
# 10.1109/vast50239.2020.00014          2
# 10.1109/vast50239.2020.00015          2
# 10.1109/visual.1998.745338            2
# 10.1109/visual.2000.885720            2
# 10.1109/visual.2004.22                2
#
# [183 rows x 1 columns]

# %%
matches[matches['vispub_doi'] == '10.1109/infvis.1995.528685']
# Out:
#                       vispub_doi                 aminer_id method
# 2095  10.1109/infvis.1995.528685  558a4774e4b0b32fcb35e104  title
# 3563  10.1109/infvis.1995.528685  635bcab890e50fcafd33d13b    doi

# %% [markdown]
# ### Get Aminer paper details

# %%
# %%time
papers = dict()
count, match_ids = 0, 0
with open("dblp_v14.json", encoding="utf8") as infile:
    for line in infile:
        line = line.strip().strip(',').strip("]'")
        if line[0] != '{':
            continue
        paper = json.loads(line)
        lower = re.sub(r'[^\w]', '', str(paper['title']).lower())
        
        # First, try to match by paper DOI
        if paper['id'] in ids:
            papers[paper['id']] = paper
            match_ids += 1
            
        count += 1 
        if (count % 1000000 == 0):
            print(count, match_ids)
    print(count, match_ids)
# Out:
# 1000000 917
# 2000000 1727
# 3000000 2633
# 4000000 3017
# 5000000 3448
# 5259858 3621
# Wall time: 6min 28s

# %%
len(ids), len(papers)
# Out:
# (3621, 3621)

# %%
with open('results/aminer_match_papers.p', 'wb') as fp:
    pickle.dump(papers, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Load Aminer paper details data

# %%
with open('results/aminer_match_papers.p', 'rb') as fp:
    papers = pickle.load(fp)
len(papers)

# %%
# Check the detail of papers with multiple Aminer ids
papers['558a4774e4b0b32fcb35e104']
# Out:
# {'id': '558a4774e4b0b32fcb35e104',
#  'title': 'The Information Mural: a technique for displaying and navigating large information spaces',
#  'doi': '10.1109/2945.722299',
#  'issue': '3',
#  'keywords': ['software visualization',
#   'antialiasing',
#   'search task',
#   'two-dimensional reduced representation',
#   'geographic information',
#   'scientific data',
#   'user interfaces',
#   'information bandwidth',
#   'browsing',
#   'antialiased compression',
#   'information retrieval',
#   'display screen',
#   'object-oriented programs',
#   'large information space navigation',
#   'color graphics',
#   'global views',
#   'color',
#   'information mural',
#   'text documents',
#   'grayscale shading',
#   'visual programming',
#   'information space browsing',
#   'information display',
#   'data visualisation',
#   'object-oriented programming',
#   'information navigation',
#   'data visualization',
#   'pixels',
#   'antialiasing techniques',
#   'information visualization',
#   'Information Mural',
#   'large information spaces',
#   'gray-scale shading',
#   'colour graphics'],
#  'lang': 'en',
#  'venue': {'raw': 'Visualization and Computer Graphics, IEEE Transactions'},
#  'year': 1998,
#  'n_citation': 322,
#  'page_start': '257',
#  'page_end': '271',
#  'volume': '4',
#  'issn': '1077-2626',
#  'isbn': '0-8186-7201-3',
#  'url': ['http://ieeexplore.ieee.org/xpl/abstractAuthors.jsp?tp=&arnumber=528685',
#   'http://ieeexplore.ieee.org/xpl/abstractAuthors.jsp?tp=&arnumber=722299',
#   'http://dx.doi.org/10.1109/2945.722299',
#   'http://doi.ieeecomputersociety.org/10.1109/2945.722299',
#   'http://dx.doi.org/10.1109/INFVIS.1995.528685',
#   'http://www.webofknowledge.com/',
#   'https://doi.org/10.1109/2945.722299',
#   'https://ieeexplore.ieee.org/document/722299/'],
#  'abstract': 'Information visualizations must allow users to browse information spaces and focus quickly on items of interest. Being able to see some representation of the entire information space provides an initial gestalt overview and gives context to support browsing and search tasks. However, the limited number of pixels on the screen constrain the information bandwidth and make it difficult to completely display large information spaces. The Information Mural is a two-dimensional, reduced representation of an entire information space that fits entirely within a display window or screen. The Mural creates a miniature version of the information space using visual attributes, such as gray-scale shading, intensity, color, and pixel size, along with antialiased compression techniques. Information Murals can be used as stand-alone visualizations or in global navigational views. We have built several prototypes to demonstrate the use of Information Murals in visualization applications; subject matter for these views includes computer software, scientific data, text documents, and geographic information. Index Terms—Information visualization, software visualization, data visualization, focus+context, navigation, browsers. ——————————F——————————',
#  'authors': [{'id': '562e92cc45cedb33992b80f4',
#    'name': 'Dean F. Jerding',
#    'org': 'Coll. of Comput., Georgia Inst. of Technol., Atlanta, GA, USA|c|'},
#   {'id': '53f43035dabfaee43ebe943d',
#    'name': 'John T. Stasko',
#    'org': 'Georgia Inst Technol, Coll Comp, Graph Visualizat & Usabil Ctr, Atlanta, GA 30332 USA'}],
#  'doc_type': 'Journal',
#  'references': ['53e9a82bb7602d9703170ed3',
#   '53e9afdab7602d9703a2aca4',
#   '53e9b5e7b7602d970413b833',
#   '557d3f6c6feeaa8086da8b25',
#   '558a5efbe4b037c08756bc8f',
#   '53e99800b7602d97020112a3',
#   '53e9980eb7602d9702027e89',
#   '53e99827b7602d9702048b0a',
#   '53e9987db7602d97020b574e',
#   '53e9987eb7602d97020ba634',
#   '53e99931b7602d970216fa18',
#   '53e99aa5b7602d970231b53d',
#   '53e99b63b7602d970240a5c0',
#   '53e9a1e7b7602d9702ae60f4',
#   '53e9a1fab7602d9702afbceb',
#   '53e9a1fbb7602d9702afe4d3',
#   '53e9a2ecb7602d9702bf60e9',
#   '53e9a366b7602d9702c7474e',
#   '53e9a388b7602d9702c97ea1',
#   '53e9a806b7602d970314948d',
#   '53e9a82bb7602d9703170ed3',
#   '53e9a84eb7602d97031963b8',
#   '53e9a914b7602d97032628b0',
#   '53e9aafab7602d970347e08c',
#   '53e9aeb1b7602d97038d7e2e',
#   '53e9af87b7602d97039d10d1',
#   '53e9afdab7602d9703a2aca4',
#   '53e9b061b7602d9703ac71f8',
#   '53e9b469b7602d9703f6b538',
#   '53e9b5e7b7602d970413b833',
#   '53e9b655b7602d97041b4f40',
#   '53e9b655b7602d97041b4f3f',
#   '53e9ba9bb7602d97046c69fe',
#   '53e9be35b7602d9704af08dc',
#   '557d3f6c6feeaa8086da8b25',
#   '557de105f6678c77ea21e36f',
#   '5583595e0cf27a8ef1245fe4',
#   '558a4774e4b0b32fcb35e104',
#   '558a4c51e4b037c087564de5',
#   '558a5efbe4b037c08756bc8f',
#   '573696d56e3b12023e5d5372']}

# %%
papers['635bcab890e50fcafd33d13b']
# Out:
# {'id': '635bcab890e50fcafd33d13b',
#  'title': 'The information mural: a technique for displaying and navigating large information spaces.',
#  'doi': '10.1109/INFVIS.1995.528685',
#  'issue': '',
#  'keywords': [],
#  'lang': '',
#  'venue': {'raw': 'IEEE Visualization Conference'},
#  'year': 1995,
#  'n_citation': 322,
#  'page_start': '43',
#  'page_end': '50',
#  'volume': '',
#  'issn': '',
#  'isbn': '',
#  'url': ['https://doi.org/10.1109/INFVIS.1995.528685'],
#  'abstract': '',
#  'authors': [{'id': '', 'name': 'Dean F. Jerding', 'org': ''},
#   {'id': '53f43035dabfaee43ebe943d', 'name': 'John T. Stasko', 'org': ''}],
#  'doc_type': 'Conference'}

# %% [markdown]
# Internal references

# %%
df = pd.read_csv("../vispubdata-update/vispubdata-update.csv", keep_default_na=False)
df['doi'] = df["DOI"].apply(lambda x: str(x).lower())
years = df.set_index('DOI')['Year'].to_dict()

# %%
cites = list()
years = dict()
for key, value in papers.items():
    years[key] = value['year']
    if 'references' in value:
        for i in value['references']:
            cites.append([key, value['year'], i])
cites = pd.DataFrame(cites, columns=['paper', 'paper_year', 'reference'])

# %%
cites
# Out:
#                           paper  paper_year                 reference
# 0      53e9be57b7602d9704b1803a        1993  557ec040d19faf961d16c238
# 1      53e9be57b7602d9704b1803a        1993  5582e4000cf2bb52dc3e032d
# 2      53e9be57b7602d9704b1803a        1993  53e99ba3b7602d970244ca1d
# 3      53e9be57b7602d9704b1803a        1993  53e99bb2b7602d970245d252
# 4      53e9be57b7602d9704b1803a        1993  53e9a8d3b7602d97032219fa
# ...                         ...         ...                       ...
# 57952  633c10ea90e50fcafdc35542        2015  53e99a98b7602d9702313574
# 57953  633c10ea90e50fcafdc35670        2015  53e9b661b7602d97041c60bc
# 57954  633c10ea90e50fcafdc35670        2015  53e99f64b7602d9702838cc0
# 57955  633c10ea90e50fcafdc35670        2015  53e99a04b7602d9702250b0b
# 57956  633c10ea90e50fcafdc35670        2015  53e9ab69b7602d970350474e
#
# [57957 rows x 3 columns]

# %%
# Filter only internal citations
cites = cites[cites['reference'].isin(ids)].copy()
cites['reference_year'] = cites['reference'].replace(years)

# %%
# Remove self citation
cites = cites[cites['paper'] != cites['reference']]

# %%
# Filter only citations that come after the paper year
cites[cites['reference_year'] > cites['paper_year']]
# Out:
#                           paper  paper_year                 reference  \
# 548    53e99827b7602d970204987c        1997  53e99b5db7602d97024026b0
# 10980  53e9a73bb7602d9703071886        2007  53e9be3cb7602d9704af7b3c
# 12321  53e9a9f7b7602d970335d8b7        2006  53e9bb67b7602d97047aa045
# 33983  558aeafbe4b037c08759f29e        2007  558c855984ae6766fdf3898f
# 34105  558aeafde4b037c08759f2ac        2007  53e9ae42b7602d9703859dbe
# 47984  5c2c7a9217c44a4e7cf31980        2018  5c8dbfa34895d9cbc69bd7cd
# 51344  5e63725b91e011ae97a69e48        2019  5d63ae47ed7e9c7926557db4
#
#        reference_year
# 548              1998
# 10980            2008
# 12321            2007
# 33983            2010
# 34105            2009
# 47984            2019
# 51344            2020

# %%
# Replace with vispubdata DOIs
cites = cites.replace(dois)

cites['paper_year'] = cites['paper'].copy().replace(years)
cites['reference_year'] = cites['reference'].copy().replace(years)

# %%
# Remove citation in the future
cites = cites[cites['reference_year'] <= cites['paper_year']]

# %%
c = cites.groupby('paper').agg({'reference': 'unique'}).reset_index()
c['reference'] = c['reference'].apply(lambda x: ';'.join(x))
c = c.set_index('paper')['reference'].to_dict()

# %% [markdown]
# ### Merge into vispubdata dataset

# %%
df = pd.read_csv("../vispubdata-update/vispubdata-update.csv", keep_default_na=False)

# %%
count = 0
for index, row in df.iterrows():
    if not row['DOI'] in list(matches['vispub_doi']):
        continue
    
    # Citation count
    m_ids = list(matches.loc[matches['vispub_doi'] == row['DOI'], 'aminer_id'])
    n_cites = max([papers[x]['n_citation'] for x in m_ids])
    df.loc[index, 'AminerCitationCount'] = n_cites
    
    # Internal references
    #if row['DOI'] in c:
    #    df.loc[index, 'internal_references'] = c[row['DOI']]
    
    count += 1

# %%
df
# Out:
#      Conference  Year                                              Title  \
# 0           Vis  2022  Photosensitive Accessibility for Interactive D...
# 1           Vis  2022  HetVis: A Visual Analysis Approach for Identif...
# 2           Vis  2022  Rigel: Transforming Tabular Data by Declarativ...
# 3           Vis  2022  BeauVis: A Validated Scale for Measuring the A...
# 4           Vis  2022  NAS-Navigator: Visual Steering for Explainable...
# ...         ...   ...                                                ...
# 3748        Vis  2023  Extract and Characterize Hairpin Vortices in T...
# 3749        Vis  2023  Causality-Based Visual Analysis of Questionnai...
# 3750        Vis  2023  Quantivine: A Visualization Approach for Large...
# 3751        Vis  2023  The Arrangement of Marks Impacts Afforded Mess...
# 3752        Vis  2023  NL2Color: Refining Color Palettes for Charts w...
#
#                             DOI                                         Link  \
# 0     10.1109/tvcg.2022.3209359  http://dx.doi.org/10.1109/TVCG.2022.3209359
# 1     10.1109/tvcg.2022.3209347  http://dx.doi.org/10.1109/TVCG.2022.3209347
# 2     10.1109/tvcg.2022.3209385  http://dx.doi.org/10.1109/TVCG.2022.3209385
# 3     10.1109/tvcg.2022.3209390  http://dx.doi.org/10.1109/TVCG.2022.3209390
# 4     10.1109/tvcg.2022.3209361  http://dx.doi.org/10.1109/TVCG.2022.3209361
# ...                         ...                                          ...
# 3748  10.1109/tvcg.2023.3326603  http://dx.doi.org/10.1109/TVCG.2023.3326603
# 3749  10.1109/tvcg.2023.3327376  http://dx.doi.org/10.1109/TVCG.2023.3327376
# 3750  10.1109/tvcg.2023.3327148  http://dx.doi.org/10.1109/TVCG.2023.3327148
# 3751  10.1109/tvcg.2023.3326590  http://dx.doi.org/10.1109/TVCG.2023.3326590
# 3752  10.1109/tvcg.2023.3326522  http://dx.doi.org/10.1109/TVCG.2023.3326522
#
#      FirstPage LastPage PaperType  \
# 0          374      384         J
# 1          310      319         J
# 2          128      138         J
# 3          363      373         J
# 4          299      309         J
# ...        ...      ...       ...
# 3748       716      726         J
# 3749       638      648         J
# 3750       573      583         J
# 3751      1008     1018         J
# 3752       814      824         J
#
#                                                Abstract  \
# 0     Accessibility guidelines place restrictions on...
# 1     Horizontal federated learning (HFL) enables di...
# 2     We present Rigel, an interactive system for ra...
# 3     We developed and validated a rating scale to a...
# 4     The success of DL can be attributed to hours o...
# ...                                                 ...
# 3748  Hairpin vortices are one of the most important...
# 3749  As the final stage of questionnaire analysis, ...
# 3750  Quantum computing is a rapidly evolving field ...
# 3751  Data visualizations present a massive number o...
# 3752  Choice of color is critical to creating effect...
#
#                                     AuthorNames-Deduped  \
# 0                        Laura South;Michelle A. Borkin
# 1     Xumeng Wang;Wei Chen 0001;Jiazhi Xia;Zhen Wen;...
# 2     Ran Chen;Di Weng;Yanwei Huang;Xinhuan Shu;Jiay...
# 3     Tingying He;Petra Isenberg;Raimund Dachselt;To...
# 4         Anjul Kumar Tyagi;Cong Xie;Klaus Mueller 0001
# ...                                                 ...
# 3748                   Adeel Zafar;Di Yang;Guoning Chen
# 3749  Renzhong Li;Weiwei Cui;Tianqi Song;Xiao Xie;Ru...
# 3750  Zhen Wen;Yihan Liu;Siwei Tan;Jieyi Chen;Minfen...
# 3751  Racquel Fygenson;Steven Franconeri;Enrico Bertini
# 3752  Chuhan Shi;Weiwei Cui;Chengzhong Liu;Chengbo Z...
#
#                                             AuthorNames  \
# 0                        Laura South;Michelle A. Borkin
# 1     Xumeng Wang;Wei Chen;Jiazhi Xia;Zhen Wen;Rongc...
# 2     Ran Chen;Di Weng;Yanwei Huang;Xinhuan Shu;Jiay...
# 3     Tingying He;Petra Isenberg;Raimund Dachselt;To...
# 4                    Anjul Tyagi;Cong Xie;Klaus Mueller
# ...                                                 ...
# 3748                   Adeel Zafar;Di Yang;Guoning Chen
# 3749  Renzhong Li;Weiwei Cui;Tianqi Song;Xiao Xie;Ru...
# 3750  Zhen Wen;Yihan Liu;Siwei Tan;Jieyi Chen;Minfen...
# 3751  Racquel Fygenson;Steven Franconeri;Enrico Bertini
# 3752  Chuhan Shi;Weiwei Cui;Chengzhong Liu;Chengbo Z...
#
#                                       AuthorAffiliation  \
# 0     Northeastern University, USA;Northeastern Univ...
# 1     TMCC, CS, Nankai University, China;State Key L...
# 2     State Key Lab of CAD&CG, Zhejiang University, ...
# 3     Université Paris-Saclay, CNRS, Inria, LISN, Fr...
# 4     Computer Science Department, Visual Analytics ...
# ...                                                 ...
# 3748  University of Houston, USA;University of Houst...
# 3749  State Key Lab of CAD&CG, Zhejiang University, ...
# 3750  State Key Lab of CAD&CG, Zhejiang University, ...
# 3751  Northeastern University, USA;Northeastern Univ...
# 3752  Southeast University, China;Microsoft Research...
#
#                                      InternalReferences  \
# 0     0.1109/tvcg.2011.185;10.1109/tvcg.2021.3114829...
# 1     0.1109/tvcg.2015.2467618;10.1109/tvcg.2019.293...
# 2     0.1109/tvcg.2021.3114830;10.1109/vast47406.201...
# 3     0.1109/infvis.2005.1532128;10.1109/tvcg.2006.1...
# 4     0.1109/vast.2012.6400490;10.1109/tvcg.2019.293...
# ...                                                 ...
# 3748  10.1109/visual.1994.346327;10.1109/tvcg.2018.2...
# 3749  10.1109/tvcg.2021.3114875;10.1109/tvcg.2022.32...
# 3750  10.1109/tvcg.2018.2865139;10.1109/infvis.2004....
# 3751  10.1109/tvcg.2012.197;10.1109/tvcg.2013.234;10...
# 3752  10.1109/tvcg.2013.234;10.1109/tvcg.2019.293478...
#
#                                          AuthorKeywords AminerCitationCount  \
# 0     accessibility,photosensitive epilepsy,photosen...
# 1     Federated learning,data heterogeneity,cluster ...
# 2     Data transformation,self-service data transfor...
# 3     Aesthetics,aesthetic pleasure,validated scale,...
# 4     Deep Learning,Neural Network Architecture Sear...
# ...                                                 ...                 ...
# 3748  Turbulent flow,vortices,hairpin vortex extraction
# 3749         Causal analysis,Questionnaire,Design study
# 3750  Quantum circuit,semantic analysis,visual abstr...
# 3751  Perception & cognition,Methodologies,Human-sub...
# 3752  chart,color palette,natural language,large lan...
#
#      CitationCount_CrossRef PubsCited_CrossRef Downloads_Xplore Award  \
# 0                         4                 63              554
# 1                        10                 43              984
# 2                         6                 68              610
# 3                         7                 79              753
# 4                         0                 63              391
# ...                     ...                ...              ...   ...
# 3748                      0                 55              165    HM
# 3749                      0                 44              304
# 3750                      0                 83              196
# 3751                      0                 67              194
# 3752                      1                 57              486
#
#      GraphicsReplicabilityStamp
# 0
# 1
# 2
# 3                             X
# 4
# ...                         ...
# 3748
# 3749
# 3750
# 3751
# 3752
#
# [3753 rows x 20 columns]

# %%
#df.to_csv('results/vispubdata_citation.csv', index=False)

# %%
df.to_csv("../vispubdata-update/vispubdata-update.csv", index=False)
